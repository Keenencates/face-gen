# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_input = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name = 'real_input')
    fake_input = tf.placeholder(tf.float32, (None, z_dim), name = 'z_input')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    return real_input, fake_input, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    alpha = 0.2
    keep_prob = .8
    with tf.variable_scope('discriminator', reuse=reuse):
        # 28 x 28 x 3
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same',
                             kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True))
        relu1 = tf.maximum(alpha * x1, x1)
        relu1 = tf.nn.dropout(relu1, keep_prob=keep_prob)
        
        # 14 x 14 x 64
        
        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same',
                             kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True))
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(alpha * bn2, bn2)
        relu2 = tf.nn.dropout(relu2, keep_prob=keep_prob)
        
        # 7 x 7 x 128
        
        x3 = tf.layers.conv2d(relu2, 256, 5, strides=1, padding='same',
                             kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True))
        bn3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(alpha * bn3, bn3)
        relu3 = tf.nn.dropout(relu3, keep_prob=keep_prob)
        
        # 7 x 7 x 256
        flat = tf.reshape(relu3, (-1, 7*7*256))
        #flat = tf.contrib.layers.flatten(relu3)
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    alpha = .2
    keep_prob = .5
    with tf.variable_scope('generator', reuse=not is_train):
        # 28 x 28 x 3
        x1 = tf.layers.dense(z, 7*7*512)
        x1 = tf.reshape(x1, (-1, 7, 7, 512))        
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(alpha * x1, x1)
        if is_train:
            x1 = tf.nn.dropout(x1, keep_prob)
        # 7 x 7 x 32
        
        x2 = tf.layers.conv2d_transpose(x1, 256, 5, strides=2, padding='same',
                                        kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True))
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(alpha * x2, x2)
        if is_train:
            x2 = tf.nn.dropout(x2, keep_prob)

        # 14 x 14 x 16
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides=2, padding='same',
                                       kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True))
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(alpha * x3, x3)
        if is_train:
            x3 = tf.nn.dropout(x3, keep_prob)
        
        # 28 x 28 x 8
        
        x4 = tf.layers.conv2d_transpose(x3, 64, 5, strides=1, padding='same',
                                       kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=True))
        x4 = tf.layers.batch_normalization(x4, training=is_train)
        x4 = tf.maximum(alpha * x4, x4)
        if is_train:
            x4 = tf.nn.dropout(x4, keep_prob)
        
        logits = tf.layers.conv2d_transpose(x4, out_channel_dim, 5, strides=1, padding='same')
        
        # 28 x 28 x 3
        
        out = tf.tanh(logits)
        
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    #d_loss_real = tf.reduce_mean(
    #    tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))
    #smoothing
    d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                         labels=tf.ones_like(d_model_real)*0.9))
    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    
    #https://discussions.udacity.com/t/project-5-net-not-training/246936/9?u=keenencatesphevy
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    all_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

    g_update_ops = [var for var in all_update_ops if var.name.startswith('generator')]
    d_update_ops = [var for var in all_update_ops if var.name.startswith('discriminator')]

    with tf.control_dependencies(d_update_ops):
        d_train = tf.train.AdamOptimizer(learning_rate, beta1 = beta1).minimize(d_loss, var_list = d_vars)

    with tf.control_dependencies(g_update_ops):
        g_train = tf.train.AdamOptimizer(learning_rate, beta1 = beta1).minimize(g_loss, var_list = g_vars)

    return d_train, g_train
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    _ , img_w, img_h, img_d = data_shape
    real_input, z_input, lr = model_inputs(img_w, img_h, img_d, z_dim)
    d_loss, g_loss = model_loss(real_input, z_input, img_d)
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    steps = 0
    losses = []
    print_every = 10
    show_every = 100
    
    figsize=(5,5)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                batch_images *= 2
                steps += 1
                z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                _ = sess.run(d_opt, feed_dict={real_input: batch_images, z_input: z, lr: learning_rate})
               # _ = sess.run(d_opt, feed_dict={real_input: batch_images, z_input: z, lr: learning_rate})
                _ = sess.run(g_opt, feed_dict={z_input: z, lr: learning_rate})
                _ = sess.run(g_opt, feed_dict={z_input: z, lr: learning_rate})
                
                if steps % print_every == 0:
                    train_loss_d = d_loss.eval({z_input: z, real_input: batch_images})
                    train_loss_g = g_loss.eval({z_input: z})

                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    losses.append((train_loss_d, train_loss_g))
                    
                if steps % show_every == 0:
                    show_generator_output(sess, 25, z_input, img_d, data_image_mode)
                    
    return losses

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = .0002
beta1 = .5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 1.3390... Generator Loss: 3.1214
# Epoch 1/2... Discriminator Loss: 1.8792... Generator Loss: 0.4760
# Epoch 1/2... Discriminator Loss: 1.2344... Generator Loss: 0.9619
# Epoch 1/2... Discriminator Loss: 0.7701... Generator Loss: 1.7728
# Epoch 1/2... Discriminator Loss: 1.0569... Generator Loss: 1.5810
# Epoch 1/2... Discriminator Loss: 1.4537... Generator Loss: 1.0697
# Epoch 1/2... Discriminator Loss: 1.4598... Generator Loss: 0.9380
# Epoch 1/2... Discriminator Loss: 1.4785... Generator Loss: 0.7985
# Epoch 1/2... Discriminator Loss: 1.3875... Generator Loss: 1.0750
# Epoch 1/2... Discriminator Loss: 1.5832... Generator Loss: 1.8686
# Epoch 1/2... Discriminator Loss: 1.3508... Generator Loss: 0.9719
# Epoch 1/2... Discriminator Loss: 1.5392... Generator Loss: 2.0707
# Epoch 1/2... Discriminator Loss: 1.4440... Generator Loss: 2.0766
# Epoch 1/2... Discriminator Loss: 1.1928... Generator Loss: 1.0281
# Epoch 1/2... Discriminator Loss: 1.7838... Generator Loss: 0.4338
# Epoch 1/2... Discriminator Loss: 1.5164... Generator Loss: 2.0724
# Epoch 1/2... Discriminator Loss: 1.2659... Generator Loss: 1.3677
# Epoch 1/2... Discriminator Loss: 1.5318... Generator Loss: 2.6838
# Epoch 1/2... Discriminator Loss: 1.3456... Generator Loss: 0.9863
# Epoch 1/2... Discriminator Loss: 1.2059... Generator Loss: 1.4728
# Epoch 1/2... Discriminator Loss: 1.3025... Generator Loss: 0.7724
# Epoch 1/2... Discriminator Loss: 1.1647... Generator Loss: 1.6115
# Epoch 1/2... Discriminator Loss: 1.1858... Generator Loss: 1.1740
# Epoch 1/2... Discriminator Loss: 1.3637... Generator Loss: 0.9844
# Epoch 1/2... Discriminator Loss: 1.2291... Generator Loss: 1.3559
# Epoch 1/2... Discriminator Loss: 1.2030... Generator Loss: 1.0562
# Epoch 1/2... Discriminator Loss: 1.3305... Generator Loss: 0.9574
# Epoch 1/2... Discriminator Loss: 1.1527... Generator Loss: 1.5945
# Epoch 1/2... Discriminator Loss: 1.3467... Generator Loss: 0.7532
# Epoch 1/2... Discriminator Loss: 1.1200... Generator Loss: 1.2835
# Epoch 1/2... Discriminator Loss: 1.4008... Generator Loss: 1.7304
# Epoch 1/2... Discriminator Loss: 1.1587... Generator Loss: 1.2976
# Epoch 1/2... Discriminator Loss: 1.3124... Generator Loss: 1.3985
# Epoch 1/2... Discriminator Loss: 1.1076... Generator Loss: 1.1392
# Epoch 1/2... Discriminator Loss: 1.2336... Generator Loss: 1.1215
# Epoch 1/2... Discriminator Loss: 1.1728... Generator Loss: 0.9591
# Epoch 1/2... Discriminator Loss: 1.2228... Generator Loss: 1.3691
# Epoch 1/2... Discriminator Loss: 1.1410... Generator Loss: 0.8734
# Epoch 1/2... Discriminator Loss: 1.6933... Generator Loss: 1.9748
# Epoch 1/2... Discriminator Loss: 1.2378... Generator Loss: 1.1216
# Epoch 1/2... Discriminator Loss: 1.2698... Generator Loss: 0.9560
# Epoch 1/2... Discriminator Loss: 1.6487... Generator Loss: 2.0136
# Epoch 1/2... Discriminator Loss: 1.3377... Generator Loss: 0.9972
# Epoch 1/2... Discriminator Loss: 1.2208... Generator Loss: 1.8688
# Epoch 1/2... Discriminator Loss: 1.5494... Generator Loss: 0.7736
# Epoch 1/2... Discriminator Loss: 1.1618... Generator Loss: 1.3692
# Epoch 1/2... Discriminator Loss: 1.2763... Generator Loss: 1.2186
# Epoch 1/2... Discriminator Loss: 1.3068... Generator Loss: 1.5648
# Epoch 1/2... Discriminator Loss: 1.3590... Generator Loss: 0.8019
# Epoch 1/2... Discriminator Loss: 1.2699... Generator Loss: 1.1088
# Epoch 1/2... Discriminator Loss: 1.2617... Generator Loss: 0.8436
# Epoch 1/2... Discriminator Loss: 1.2848... Generator Loss: 1.2616
# Epoch 1/2... Discriminator Loss: 1.2948... Generator Loss: 0.9277
# Epoch 1/2... Discriminator Loss: 1.1018... Generator Loss: 1.5475
# Epoch 1/2... Discriminator Loss: 1.4525... Generator Loss: 0.7086
# Epoch 1/2... Discriminator Loss: 1.3302... Generator Loss: 0.7990
# Epoch 1/2... Discriminator Loss: 1.2753... Generator Loss: 0.9146
# Epoch 1/2... Discriminator Loss: 1.2228... Generator Loss: 1.0034
# Epoch 1/2... Discriminator Loss: 1.3303... Generator Loss: 0.8244
# Epoch 1/2... Discriminator Loss: 1.0690... Generator Loss: 0.9748
# Epoch 1/2... Discriminator Loss: 1.2793... Generator Loss: 1.6331
# Epoch 1/2... Discriminator Loss: 1.2643... Generator Loss: 0.7291
# Epoch 1/2... Discriminator Loss: 1.0933... Generator Loss: 1.2444
# Epoch 1/2... Discriminator Loss: 1.2338... Generator Loss: 0.8465
# Epoch 1/2... Discriminator Loss: 1.2310... Generator Loss: 1.0235
# Epoch 1/2... Discriminator Loss: 1.3538... Generator Loss: 1.4412
# Epoch 1/2... Discriminator Loss: 1.2407... Generator Loss: 1.1373
# Epoch 1/2... Discriminator Loss: 1.1727... Generator Loss: 0.9324
# Epoch 1/2... Discriminator Loss: 1.3499... Generator Loss: 1.1521
# Epoch 1/2... Discriminator Loss: 1.1837... Generator Loss: 0.9932
# Epoch 1/2... Discriminator Loss: 1.4955... Generator Loss: 1.4338
# Epoch 1/2... Discriminator Loss: 1.3530... Generator Loss: 1.1526
# Epoch 1/2... Discriminator Loss: 1.3763... Generator Loss: 1.1271
# Epoch 1/2... Discriminator Loss: 1.1012... Generator Loss: 1.1381
# Epoch 1/2... Discriminator Loss: 1.1981... Generator Loss: 1.5241
# Epoch 1/2... Discriminator Loss: 1.1593... Generator Loss: 1.0691
# Epoch 1/2... Discriminator Loss: 1.2182... Generator Loss: 1.1709
# Epoch 1/2... Discriminator Loss: 1.2154... Generator Loss: 1.6065
# Epoch 1/2... Discriminator Loss: 1.3322... Generator Loss: 0.9660
# Epoch 1/2... Discriminator Loss: 1.1714... Generator Loss: 1.3818
# Epoch 1/2... Discriminator Loss: 1.1871... Generator Loss: 1.2124
# Epoch 1/2... Discriminator Loss: 1.3571... Generator Loss: 0.6422
# Epoch 1/2... Discriminator Loss: 1.1687... Generator Loss: 1.2640
# Epoch 1/2... Discriminator Loss: 1.2476... Generator Loss: 1.0067
# Epoch 1/2... Discriminator Loss: 1.1626... Generator Loss: 1.1026
# Epoch 1/2... Discriminator Loss: 1.2753... Generator Loss: 1.6081
# Epoch 1/2... Discriminator Loss: 1.2918... Generator Loss: 1.4782
# Epoch 1/2... Discriminator Loss: 1.3210... Generator Loss: 0.8273
# Epoch 1/2... Discriminator Loss: 1.1208... Generator Loss: 1.1132
# Epoch 1/2... Discriminator Loss: 1.2291... Generator Loss: 1.3507
# Epoch 1/2... Discriminator Loss: 1.2773... Generator Loss: 1.2203
# Epoch 1/2... Discriminator Loss: 1.1070... Generator Loss: 1.3507
# Epoch 1/2... Discriminator Loss: 1.1859... Generator Loss: 1.2989
# Epoch 2/2... Discriminator Loss: 1.2545... Generator Loss: 1.7048
# Epoch 2/2... Discriminator Loss: 1.2568... Generator Loss: 1.3538
# Epoch 2/2... Discriminator Loss: 1.1644... Generator Loss: 0.8493
# Epoch 2/2... Discriminator Loss: 1.1702... Generator Loss: 0.9515
# Epoch 2/2... Discriminator Loss: 1.3238... Generator Loss: 0.7955
# Epoch 2/2... Discriminator Loss: 1.1574... Generator Loss: 0.9806
# Epoch 2/2... Discriminator Loss: 1.1580... Generator Loss: 1.8667
# Epoch 2/2... Discriminator Loss: 1.0723... Generator Loss: 1.1842
# Epoch 2/2... Discriminator Loss: 1.2901... Generator Loss: 0.9858
# Epoch 2/2... Discriminator Loss: 1.3833... Generator Loss: 1.6551
# Epoch 2/2... Discriminator Loss: 1.2063... Generator Loss: 1.3931
# Epoch 2/2... Discriminator Loss: 1.3003... Generator Loss: 0.7998
# Epoch 2/2... Discriminator Loss: 1.4421... Generator Loss: 0.6051
# Epoch 2/2... Discriminator Loss: 1.1689... Generator Loss: 1.4486
# Epoch 2/2... Discriminator Loss: 1.2160... Generator Loss: 1.0339
# Epoch 2/2... Discriminator Loss: 1.1987... Generator Loss: 1.3015
# Epoch 2/2... Discriminator Loss: 1.1178... Generator Loss: 1.0433
# Epoch 2/2... Discriminator Loss: 1.3026... Generator Loss: 0.7455
# Epoch 2/2... Discriminator Loss: 1.2494... Generator Loss: 1.0781
# Epoch 2/2... Discriminator Loss: 1.2566... Generator Loss: 0.9280
# Epoch 2/2... Discriminator Loss: 1.2004... Generator Loss: 1.4479
# Epoch 2/2... Discriminator Loss: 1.2557... Generator Loss: 0.7037
# Epoch 2/2... Discriminator Loss: 1.2496... Generator Loss: 1.3156
# Epoch 2/2... Discriminator Loss: 1.1481... Generator Loss: 1.1181
# Epoch 2/2... Discriminator Loss: 1.1921... Generator Loss: 0.8669
# Epoch 2/2... Discriminator Loss: 1.2570... Generator Loss: 1.2484
# Epoch 2/2... Discriminator Loss: 1.5286... Generator Loss: 1.7433
# Epoch 2/2... Discriminator Loss: 1.2300... Generator Loss: 0.9921
# Epoch 2/2... Discriminator Loss: 1.1288... Generator Loss: 1.0204
# Epoch 2/2... Discriminator Loss: 1.1403... Generator Loss: 1.1773
# Epoch 2/2... Discriminator Loss: 1.2038... Generator Loss: 1.0714
# Epoch 2/2... Discriminator Loss: 1.1704... Generator Loss: 0.9008
# Epoch 2/2... Discriminator Loss: 1.2138... Generator Loss: 0.8330
# Epoch 2/2... Discriminator Loss: 1.2323... Generator Loss: 0.8593
# Epoch 2/2... Discriminator Loss: 1.2236... Generator Loss: 0.9469
# Epoch 2/2... Discriminator Loss: 1.1722... Generator Loss: 1.1084
# Epoch 2/2... Discriminator Loss: 1.1778... Generator Loss: 0.8143
# Epoch 2/2... Discriminator Loss: 1.2272... Generator Loss: 1.3775
# Epoch 2/2... Discriminator Loss: 1.2779... Generator Loss: 1.4158
# Epoch 2/2... Discriminator Loss: 1.1528... Generator Loss: 1.5193
# Epoch 2/2... Discriminator Loss: 1.2016... Generator Loss: 1.1704
# Epoch 2/2... Discriminator Loss: 1.3379... Generator Loss: 0.7859
# Epoch 2/2... Discriminator Loss: 1.2000... Generator Loss: 1.0192
# Epoch 2/2... Discriminator Loss: 1.2628... Generator Loss: 1.5084
# Epoch 2/2... Discriminator Loss: 1.1978... Generator Loss: 1.1264
# Epoch 2/2... Discriminator Loss: 1.2926... Generator Loss: 0.9347
# Epoch 2/2... Discriminator Loss: 1.4289... Generator Loss: 0.6723
# Epoch 2/2... Discriminator Loss: 1.1938... Generator Loss: 1.3354
# Epoch 2/2... Discriminator Loss: 1.2435... Generator Loss: 1.2763
# Epoch 2/2... Discriminator Loss: 1.1317... Generator Loss: 1.0890
# Epoch 2/2... Discriminator Loss: 1.2667... Generator Loss: 0.8714
# Epoch 2/2... Discriminator Loss: 1.2923... Generator Loss: 1.5001
# Epoch 2/2... Discriminator Loss: 1.2491... Generator Loss: 1.1680
# Epoch 2/2... Discriminator Loss: 1.2670... Generator Loss: 1.2643
# Epoch 2/2... Discriminator Loss: 1.1975... Generator Loss: 1.2305
# Epoch 2/2... Discriminator Loss: 1.2276... Generator Loss: 1.0102
# Epoch 2/2... Discriminator Loss: 1.1603... Generator Loss: 0.9971
# Epoch 2/2... Discriminator Loss: 1.2125... Generator Loss: 1.5018
# Epoch 2/2... Discriminator Loss: 1.2073... Generator Loss: 0.9881
# Epoch 2/2... Discriminator Loss: 1.3556... Generator Loss: 1.1870
# Epoch 2/2... Discriminator Loss: 1.2362... Generator Loss: 1.6135
# Epoch 2/2... Discriminator Loss: 1.1819... Generator Loss: 1.1561
# Epoch 2/2... Discriminator Loss: 1.1970... Generator Loss: 0.8243
# Epoch 2/2... Discriminator Loss: 1.0944... Generator Loss: 1.1345
# Epoch 2/2... Discriminator Loss: 1.2333... Generator Loss: 0.7309
# Epoch 2/2... Discriminator Loss: 1.2618... Generator Loss: 1.0458
# Epoch 2/2... Discriminator Loss: 1.3890... Generator Loss: 1.7355
# Epoch 2/2... Discriminator Loss: 1.4962... Generator Loss: 0.5413
# Epoch 2/2... Discriminator Loss: 1.2218... Generator Loss: 1.2062
# Epoch 2/2... Discriminator Loss: 1.2417... Generator Loss: 1.0820
# Epoch 2/2... Discriminator Loss: 1.1846... Generator Loss: 1.1540
# Epoch 2/2... Discriminator Loss: 1.2023... Generator Loss: 1.3248
# Epoch 2/2... Discriminator Loss: 1.3064... Generator Loss: 1.4103
# Epoch 2/2... Discriminator Loss: 1.1442... Generator Loss: 1.1531
# Epoch 2/2... Discriminator Loss: 1.2180... Generator Loss: 1.2336
# Epoch 2/2... Discriminator Loss: 1.3185... Generator Loss: 1.1776
# Epoch 2/2... Discriminator Loss: 1.2485... Generator Loss: 1.1019
# Epoch 2/2... Discriminator Loss: 1.2084... Generator Loss: 1.1891
# Epoch 2/2... Discriminator Loss: 1.2507... Generator Loss: 0.8794
# Epoch 2/2... Discriminator Loss: 1.3033... Generator Loss: 1.1807
# Epoch 2/2... Discriminator Loss: 1.2023... Generator Loss: 1.4627
# Epoch 2/2... Discriminator Loss: 1.1542... Generator Loss: 1.0297
# Epoch 2/2... Discriminator Loss: 1.2146... Generator Loss: 0.9473
# Epoch 2/2... Discriminator Loss: 1.2757... Generator Loss: 1.2371
# Epoch 2/2... Discriminator Loss: 1.2126... Generator Loss: 1.1553
# Epoch 2/2... Discriminator Loss: 1.2510... Generator Loss: 1.1474
# Epoch 2/2... Discriminator Loss: 1.3226... Generator Loss: 1.2902
# Epoch 2/2... Discriminator Loss: 1.2252... Generator Loss: 1.3628
# Epoch 2/2... Discriminator Loss: 1.2116... Generator Loss: 1.0152
# Epoch 2/2... Discriminator Loss: 1.1750... Generator Loss: 1.2908
# Epoch 2/2... Discriminator Loss: 1.1407... Generator Loss: 1.2247
# Epoch 2/2... Discriminator Loss: 1.0967... Generator Loss: 1.1522
# Epoch 2/2... Discriminator Loss: 1.2322... Generator Loss: 1.3378
# Epoch 2/2... Discriminator Loss: 1.1623... Generator Loss: 1.1145

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = .0002
beta1 = .5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 0.5934... Generator Loss: 3.8897
# Epoch 1/1... Discriminator Loss: 0.6052... Generator Loss: 2.3609
# Epoch 1/1... Discriminator Loss: 0.9222... Generator Loss: 1.8593
# Epoch 1/1... Discriminator Loss: 0.6853... Generator Loss: 2.7110
# Epoch 1/1... Discriminator Loss: 0.7569... Generator Loss: 2.0305
# Epoch 1/1... Discriminator Loss: 0.5587... Generator Loss: 3.1029
# Epoch 1/1... Discriminator Loss: 0.4931... Generator Loss: 3.0547
# Epoch 1/1... Discriminator Loss: 0.5042... Generator Loss: 3.8651
# Epoch 1/1... Discriminator Loss: 0.5334... Generator Loss: 4.3531
# Epoch 1/1... Discriminator Loss: 0.4962... Generator Loss: 2.8865
# Epoch 1/1... Discriminator Loss: 0.4886... Generator Loss: 3.1002
# Epoch 1/1... Discriminator Loss: 0.5818... Generator Loss: 3.8064
# Epoch 1/1... Discriminator Loss: 0.5415... Generator Loss: 2.8201
# Epoch 1/1... Discriminator Loss: 0.6089... Generator Loss: 2.5577
# Epoch 1/1... Discriminator Loss: 0.6471... Generator Loss: 2.8780
# Epoch 1/1... Discriminator Loss: 1.7500... Generator Loss: 0.5014
# Epoch 1/1... Discriminator Loss: 0.6080... Generator Loss: 2.7025
# Epoch 1/1... Discriminator Loss: 0.8832... Generator Loss: 3.6987
# Epoch 1/1... Discriminator Loss: 0.8974... Generator Loss: 1.7397
# Epoch 1/1... Discriminator Loss: 1.1927... Generator Loss: 0.8641
# Epoch 1/1... Discriminator Loss: 1.1573... Generator Loss: 3.4185
# Epoch 1/1... Discriminator Loss: 1.2914... Generator Loss: 0.9515
# Epoch 1/1... Discriminator Loss: 0.8674... Generator Loss: 2.9400
# Epoch 1/1... Discriminator Loss: 1.2952... Generator Loss: 2.7978
# Epoch 1/1... Discriminator Loss: 1.1175... Generator Loss: 1.6472
# Epoch 1/1... Discriminator Loss: 0.7901... Generator Loss: 1.6335
# Epoch 1/1... Discriminator Loss: 1.5639... Generator Loss: 0.7999
# Epoch 1/1... Discriminator Loss: 1.1974... Generator Loss: 1.3369
# Epoch 1/1... Discriminator Loss: 1.2752... Generator Loss: 2.6094
# Epoch 1/1... Discriminator Loss: 1.2011... Generator Loss: 0.7959
# Epoch 1/1... Discriminator Loss: 0.8998... Generator Loss: 1.5864
# Epoch 1/1... Discriminator Loss: 1.1016... Generator Loss: 1.4893
# Epoch 1/1... Discriminator Loss: 1.5273... Generator Loss: 1.3314
# Epoch 1/1... Discriminator Loss: 1.4046... Generator Loss: 0.6961
# Epoch 1/1... Discriminator Loss: 0.9866... Generator Loss: 1.3931
# Epoch 1/1... Discriminator Loss: 1.2808... Generator Loss: 0.7866
# Epoch 1/1... Discriminator Loss: 1.5661... Generator Loss: 1.2441
# Epoch 1/1... Discriminator Loss: 1.3698... Generator Loss: 1.2046
# Epoch 1/1... Discriminator Loss: 1.4289... Generator Loss: 2.0416
# Epoch 1/1... Discriminator Loss: 1.2583... Generator Loss: 0.9942
# Epoch 1/1... Discriminator Loss: 1.3699... Generator Loss: 0.8748
# Epoch 1/1... Discriminator Loss: 1.5478... Generator Loss: 1.0594
# Epoch 1/1... Discriminator Loss: 1.4076... Generator Loss: 0.9853
# Epoch 1/1... Discriminator Loss: 1.4648... Generator Loss: 0.8938
# Epoch 1/1... Discriminator Loss: 1.2661... Generator Loss: 1.3711
# Epoch 1/1... Discriminator Loss: 1.4320... Generator Loss: 1.0918
# Epoch 1/1... Discriminator Loss: 1.5695... Generator Loss: 0.8514
# Epoch 1/1... Discriminator Loss: 1.6411... Generator Loss: 0.8649
# Epoch 1/1... Discriminator Loss: 1.2625... Generator Loss: 0.8744
# Epoch 1/1... Discriminator Loss: 1.4906... Generator Loss: 0.8853
# Epoch 1/1... Discriminator Loss: 1.6413... Generator Loss: 0.8342
# Epoch 1/1... Discriminator Loss: 1.5105... Generator Loss: 0.9065
# Epoch 1/1... Discriminator Loss: 1.3360... Generator Loss: 1.0981
# Epoch 1/1... Discriminator Loss: 1.3128... Generator Loss: 0.8657
# Epoch 1/1... Discriminator Loss: 1.4579... Generator Loss: 0.8766
# Epoch 1/1... Discriminator Loss: 1.8391... Generator Loss: 0.7744
# Epoch 1/1... Discriminator Loss: 1.2516... Generator Loss: 1.2349
# Epoch 1/1... Discriminator Loss: 1.4555... Generator Loss: 1.0200
# Epoch 1/1... Discriminator Loss: 1.5240... Generator Loss: 0.8974
# Epoch 1/1... Discriminator Loss: 1.3452... Generator Loss: 0.8380
# Epoch 1/1... Discriminator Loss: 1.6144... Generator Loss: 0.8650
# Epoch 1/1... Discriminator Loss: 1.2179... Generator Loss: 1.2141
# Epoch 1/1... Discriminator Loss: 1.5358... Generator Loss: 1.0440
# Epoch 1/1... Discriminator Loss: 1.4844... Generator Loss: 0.8560
# Epoch 1/1... Discriminator Loss: 1.4214... Generator Loss: 1.0704
# Epoch 1/1... Discriminator Loss: 1.4970... Generator Loss: 0.9733
# Epoch 1/1... Discriminator Loss: 1.5833... Generator Loss: 0.8792
# Epoch 1/1... Discriminator Loss: 1.4580... Generator Loss: 0.8194
# Epoch 1/1... Discriminator Loss: 1.5290... Generator Loss: 0.8727
# Epoch 1/1... Discriminator Loss: 1.3046... Generator Loss: 0.9880
# Epoch 1/1... Discriminator Loss: 1.3518... Generator Loss: 0.9579
# Epoch 1/1... Discriminator Loss: 1.5203... Generator Loss: 0.8214

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
